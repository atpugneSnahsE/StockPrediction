# %%
import pandas as pd
df = pd.read_csv('AAPL.csv')
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099584
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094388
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087461
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089625
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092224
# ...           ...         ...         ...         ...         ...         ...
# 10736  2023-07-17  191.899994  194.320007  191.809998  193.990005  193.990005
# 10737  2023-07-18  193.350006  194.330002  192.419998  193.729996  193.729996
# 10738  2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 10739  2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
# 10740  2023-07-21  194.100006  194.970001  191.229996  191.940002  191.940002
#
#           Volume
# 0      469033600
# 1      175884800
# 2      105728000
# 3       86441600
# 4       73449600
# ...          ...
# 10736   50520200
# 10737   48353800
# 10738   80507300
# 10739   59581200
# 10740   71917800
#
# [10741 rows x 7 columns]

# %%
df = df[['Date', 'Close']]
df
# Out:
#              Date       Close
# 0      1980-12-12    0.128348
# 1      1980-12-15    0.121652
# 2      1980-12-16    0.112723
# 3      1980-12-17    0.115513
# 4      1980-12-18    0.118862
# ...           ...         ...
# 10736  2023-07-17  193.990005
# 10737  2023-07-18  193.729996
# 10738  2023-07-19  195.100006
# 10739  2023-07-20  193.130005
# 10740  2023-07-21  191.940002
#
# [10741 rows x 2 columns]

# %%
df['Date']
# Out:
# 0        1980-12-12
# 1        1980-12-15
# 2        1980-12-16
# 3        1980-12-17
# 4        1980-12-18
#             ...
# 10736    2023-07-17
# 10737    2023-07-18
# 10738    2023-07-19
# 10739    2023-07-20
# 10740    2023-07-21
# Name: Date, Length: 10741, dtype: object

# %%
from os.path import split
import datetime
def str_to_datetime(s):
  split=s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)
  datetime_object = str_to_datetime('1986-03-19')

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-6-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0       1980-12-12
# 1       1980-12-15
# 2       1980-12-16
# 3       1980-12-17
# 4       1980-12-18
#            ...
# 10736   2023-07-17
# 10737   2023-07-18
# 10738   2023-07-19
# 10739   2023-07-20
# 10740   2023-07-21
# Name: Date, Length: 10741, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
import matplotlib.pyplot as plt
plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  123.389999  122.540001  120.089996  120.589996
# 1    2021-03-26  122.540001  120.089996  120.589996  121.209999
# 2    2021-03-29  120.089996  120.589996  121.209999  121.389999
# 3    2021-03-30  120.589996  121.209999  121.389999  119.900002
# 4    2021-03-31  121.209999  121.389999  119.900002  122.150002
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  150.619995  155.089996  159.589996  160.619995
# 248  2022-03-18  155.089996  159.589996  160.619995  163.979996
# 249  2022-03-21  159.589996  160.619995  163.979996  165.380005
# 250  2022-03-22  160.619995  163.979996  165.380005  168.820007
# 251  2022-03-23  163.979996  165.380005  168.820007  170.210007
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 8s 132ms/step - loss: 21252.4180 - mean_absolute_error: 144.9926 - val_loss: 28688.2051 - val_mean_absolute_error: 169.2886
# Epoch 2/100
# 7/7 [==============================] - 0s 13ms/step - loss: 21126.4551 - mean_absolute_error: 144.5558 - val_loss: 28552.3457 - val_mean_absolute_error: 168.8869
# Epoch 3/100
# 7/7 [==============================] - 0s 15ms/step - loss: 20998.4375 - mean_absolute_error: 144.1126 - val_loss: 28380.0605 - val_mean_absolute_error: 168.3760
# Epoch 4/100
# 7/7 [==============================] - 0s 16ms/step - loss: 20832.7637 - mean_absolute_error: 143.5375 - val_loss: 28151.2266 - val_mean_absolute_error: 167.6951
# Epoch 5/100
# 7/7 [==============================] - 0s 16ms/step - loss: 20615.1426 - mean_absolute_error: 142.7774 - val_loss: 27838.2441 - val_mean_absolute_error: 166.7593
# Epoch 6/100
# 7/7 [==============================] - 0s 17ms/step - loss: 20299.8164 - mean_absolute_error: 141.6643 - val_loss: 27376.5566 - val_mean_absolute_error: 165.3693
# Epoch 7/100
# 7/7 [==============================] - 0s 16ms/step - loss: 19864.8027 - mean_absolute_error: 140.1235 - val_loss: 26792.8809 - val_mean_absolute_error: 163.5947
# Epoch 8/100
# 7/7 [==============================] - 0s 12ms/step - loss: 19273.5293 - mean_absolute_error: 137.9884 - val_loss: 25932.2246 - val_mean_absolute_error: 160.9421
# Epoch 9/100
# 7/7 [==============================] - 0s 15ms/step - loss: 18359.8203 - mean_absolute_error: 134.6376 - val_loss: 24557.1348 - val_mean_absolute_error: 156.6116
# Epoch 10/100
# 7/7 [==============================] - 0s 15ms/step - loss: 17093.3223 - mean_absolute_error: 129.8245 - val_loss: 22919.0898 - val_mean_absolute_error: 151.2925
# Epoch 11/100
# 7/7 [==============================] - 0s 15ms/step - loss: 15715.0303 - mean_absolute_error: 124.3999 - val_loss: 21148.5820 - val_mean_absolute_error: 145.3220
# Epoch 12/100
# 7/7 [==============================] - 0s 15ms/step - loss: 13995.9316 - mean_absolute_error: 117.2865 - val_loss: 18764.8105 - val_mean_absolute_error: 136.8750
# Epoch 13/100
# 7/7 [==============================] - 0s 16ms/step - loss: 12019.0986 - mean_absolute_error: 108.5578 - val_loss: 16319.2783 - val_mean_absolute_error: 127.6286
# Epoch 14/100
# 7/7 [==============================] - 0s 16ms/step - loss: 9953.6348 - mean_absolute_error: 98.5267 - val_loss: 13573.8428 - val_mean_absolute_error: 116.3777
# Epoch 15/100
# 7/7 [==============================] - 0s 15ms/step - loss: 7810.6685 - mean_absolute_error: 86.9574 - val_loss: 10840.5400 - val_mean_absolute_error: 103.9736
# Epoch 16/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5688.4414 - mean_absolute_error: 73.7182 - val_loss: 8013.1348 - val_mean_absolute_error: 89.3465
# Epoch 17/100
# 7/7 [==============================] - 0s 12ms/step - loss: 3634.2852 - mean_absolute_error: 58.1622 - val_loss: 5358.2861 - val_mean_absolute_error: 72.9944
# Epoch 18/100
# 7/7 [==============================] - 0s 15ms/step - loss: 2025.4984 - mean_absolute_error: 42.1591 - val_loss: 3330.5852 - val_mean_absolute_error: 57.4507
# Epoch 19/100
# 7/7 [==============================] - 0s 13ms/step - loss: 960.7600 - mean_absolute_error: 26.7460 - val_loss: 1829.7389 - val_mean_absolute_error: 42.4215
# Epoch 20/100
# 7/7 [==============================] - 0s 15ms/step - loss: 409.1035 - mean_absolute_error: 15.8376 - val_loss: 926.8262 - val_mean_absolute_error: 29.9497
# Epoch 21/100
# 7/7 [==============================] - 0s 13ms/step - loss: 243.1630 - mean_absolute_error: 12.1159 - val_loss: 522.4537 - val_mean_absolute_error: 22.2001
# Epoch 22/100
# 7/7 [==============================] - 0s 14ms/step - loss: 246.1844 - mean_absolute_error: 12.2340 - val_loss: 399.6840 - val_mean_absolute_error: 19.2390
# Epoch 23/100
# 7/7 [==============================] - 0s 18ms/step - loss: 257.6983 - mean_absolute_error: 12.7731 - val_loss: 419.7181 - val_mean_absolute_error: 19.7529
# Epoch 24/100
# 7/7 [==============================] - 0s 16ms/step - loss: 248.5076 - mean_absolute_error: 12.3522 - val_loss: 479.2980 - val_mean_absolute_error: 21.2075
# Epoch 25/100
# 7/7 [==============================] - 0s 19ms/step - loss: 236.7106 - mean_absolute_error: 11.8896 - val_loss: 555.3384 - val_mean_absolute_error: 22.9303
# Epoch 26/100
# 7/7 [==============================] - 0s 14ms/step - loss: 230.1479 - mean_absolute_error: 11.6548 - val_loss: 616.8320 - val_mean_absolute_error: 24.2341
# Epoch 27/100
# 7/7 [==============================] - 0s 13ms/step - loss: 229.4443 - mean_absolute_error: 11.6721 - val_loss: 653.8950 - val_mean_absolute_error: 24.9873
# Epoch 28/100
# 7/7 [==============================] - 0s 13ms/step - loss: 228.2474 - mean_absolute_error: 11.6905 - val_loss: 676.5242 - val_mean_absolute_error: 25.4428
# Epoch 29/100
# 7/7 [==============================] - 0s 11ms/step - loss: 223.3735 - mean_absolute_error: 11.6323 - val_loss: 688.4700 - val_mean_absolute_error: 25.6901
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 219.0192 - mean_absolute_error: 11.4824 - val_loss: 635.9678 - val_mean_absolute_error: 24.6408
# Epoch 31/100
# 7/7 [==============================] - 0s 8ms/step - loss: 217.9149 - mean_absolute_error: 11.3976 - val_loss: 620.0888 - val_mean_absolute_error: 24.3247
# Epoch 32/100
# 7/7 [==============================] - 0s 9ms/step - loss: 216.6629 - mean_absolute_error: 11.3722 - val_loss: 597.4296 - val_mean_absolute_error: 23.8557
# Epoch 33/100
# 7/7 [==============================] - 0s 9ms/step - loss: 216.6338 - mean_absolute_error: 11.2956 - val_loss: 561.8711 - val_mean_absolute_error: 23.0951
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 216.0610 - mean_absolute_error: 11.2938 - val_loss: 587.3210 - val_mean_absolute_error: 23.6477
# Epoch 35/100
# 7/7 [==============================] - 0s 12ms/step - loss: 215.6920 - mean_absolute_error: 11.3248 - val_loss: 598.6088 - val_mean_absolute_error: 23.8846
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 213.4108 - mean_absolute_error: 11.2291 - val_loss: 583.5396 - val_mean_absolute_error: 23.5662
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 208.5204 - mean_absolute_error: 11.1354 - val_loss: 633.4294 - val_mean_absolute_error: 24.6160
# Epoch 38/100
# 7/7 [==============================] - 0s 13ms/step - loss: 207.6518 - mean_absolute_error: 11.1401 - val_loss: 568.2896 - val_mean_absolute_error: 23.2498
# Epoch 39/100
# 7/7 [==============================] - 0s 9ms/step - loss: 201.2536 - mean_absolute_error: 10.8983 - val_loss: 588.4102 - val_mean_absolute_error: 23.7035
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 197.1082 - mean_absolute_error: 10.9233 - val_loss: 587.6674 - val_mean_absolute_error: 23.7020
# Epoch 41/100
# 7/7 [==============================] - 0s 9ms/step - loss: 177.4020 - mean_absolute_error: 10.2772 - val_loss: 554.8816 - val_mean_absolute_error: 23.0206
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 162.7628 - mean_absolute_error: 9.7651 - val_loss: 613.6409 - val_mean_absolute_error: 24.2999
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 152.1759 - mean_absolute_error: 9.5985 - val_loss: 432.6176 - val_mean_absolute_error: 20.2270
# Epoch 44/100
# 7/7 [==============================] - 0s 11ms/step - loss: 136.2623 - mean_absolute_error: 8.9659 - val_loss: 411.8912 - val_mean_absolute_error: 19.7588
# Epoch 45/100
# 7/7 [==============================] - 0s 9ms/step - loss: 117.8764 - mean_absolute_error: 8.1241 - val_loss: 364.4530 - val_mean_absolute_error: 18.5502
# Epoch 46/100
# 7/7 [==============================] - 0s 9ms/step - loss: 103.1348 - mean_absolute_error: 7.5185 - val_loss: 306.0533 - val_mean_absolute_error: 16.9055
# Epoch 47/100
# 7/7 [==============================] - 0s 9ms/step - loss: 89.2902 - mean_absolute_error: 6.9625 - val_loss: 337.5809 - val_mean_absolute_error: 17.9180
# Epoch 48/100
# 7/7 [==============================] - 0s 9ms/step - loss: 78.2570 - mean_absolute_error: 6.4701 - val_loss: 199.8989 - val_mean_absolute_error: 13.4203
# Epoch 49/100
# 7/7 [==============================] - 0s 10ms/step - loss: 73.8749 - mean_absolute_error: 6.4168 - val_loss: 183.8609 - val_mean_absolute_error: 12.8916
# Epoch 50/100
# 7/7 [==============================] - 0s 9ms/step - loss: 60.2286 - mean_absolute_error: 5.8347 - val_loss: 192.4289 - val_mean_absolute_error: 13.3222
# Epoch 51/100
# 7/7 [==============================] - 0s 10ms/step - loss: 43.0828 - mean_absolute_error: 4.6410 - val_loss: 148.9890 - val_mean_absolute_error: 11.5666
# Epoch 52/100
# 7/7 [==============================] - 0s 10ms/step - loss: 33.4441 - mean_absolute_error: 3.8888 - val_loss: 119.3909 - val_mean_absolute_error: 10.2269
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 25.6059 - mean_absolute_error: 3.3148 - val_loss: 88.6532 - val_mean_absolute_error: 8.5991
# Epoch 54/100
# 7/7 [==============================] - 0s 9ms/step - loss: 21.1651 - mean_absolute_error: 2.8599 - val_loss: 80.2493 - val_mean_absolute_error: 8.1636
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 20.8832 - mean_absolute_error: 3.2317 - val_loss: 62.6189 - val_mean_absolute_error: 7.0253
# Epoch 56/100
# 7/7 [==============================] - 0s 9ms/step - loss: 17.1210 - mean_absolute_error: 2.8076 - val_loss: 42.7903 - val_mean_absolute_error: 5.4533
# Epoch 57/100
# 7/7 [==============================] - 0s 9ms/step - loss: 14.4053 - mean_absolute_error: 2.5778 - val_loss: 27.4559 - val_mean_absolute_error: 4.4361
# Epoch 58/100
# 7/7 [==============================] - 0s 10ms/step - loss: 14.6680 - mean_absolute_error: 2.8759 - val_loss: 21.1427 - val_mean_absolute_error: 3.9925
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 15.4006 - mean_absolute_error: 2.9582 - val_loss: 18.9799 - val_mean_absolute_error: 3.7352
# Epoch 60/100
# 7/7 [==============================] - 0s 10ms/step - loss: 13.2656 - mean_absolute_error: 2.7670 - val_loss: 17.9609 - val_mean_absolute_error: 3.5909
# Epoch 61/100
# 7/7 [==============================] - 0s 10ms/step - loss: 11.0156 - mean_absolute_error: 2.4577 - val_loss: 17.1057 - val_mean_absolute_error: 3.4685
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 8.9053 - mean_absolute_error: 2.1657 - val_loss: 17.9740 - val_mean_absolute_error: 3.4218
# Epoch 63/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.9527 - mean_absolute_error: 1.9999 - val_loss: 19.6715 - val_mean_absolute_error: 3.4254
# Epoch 64/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7.4791 - mean_absolute_error: 1.9449 - val_loss: 15.3719 - val_mean_absolute_error: 3.1389
# Epoch 65/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7.0352 - mean_absolute_error: 1.9188 - val_loss: 13.0762 - val_mean_absolute_error: 2.9640
# Epoch 66/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7.2527 - mean_absolute_error: 2.0046 - val_loss: 12.3956 - val_mean_absolute_error: 2.8635
# Epoch 67/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.5438 - mean_absolute_error: 1.8612 - val_loss: 13.0932 - val_mean_absolute_error: 2.8471
# Epoch 68/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.5937 - mean_absolute_error: 1.8952 - val_loss: 14.4417 - val_mean_absolute_error: 2.8730
# Epoch 69/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.7378 - mean_absolute_error: 1.9617 - val_loss: 11.9262 - val_mean_absolute_error: 2.7281
# Epoch 70/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.9496 - mean_absolute_error: 1.8088 - val_loss: 11.8161 - val_mean_absolute_error: 2.9195
# Epoch 71/100
# 7/7 [==============================] - 0s 10ms/step - loss: 8.0988 - mean_absolute_error: 2.2818 - val_loss: 12.5311 - val_mean_absolute_error: 3.0288
# Epoch 72/100
# 7/7 [==============================] - 0s 10ms/step - loss: 8.0891 - mean_absolute_error: 2.3553 - val_loss: 11.2170 - val_mean_absolute_error: 2.8252
# Epoch 73/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7.1689 - mean_absolute_error: 2.0962 - val_loss: 11.0732 - val_mean_absolute_error: 2.7774
# Epoch 74/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7.6376 - mean_absolute_error: 2.1710 - val_loss: 10.9051 - val_mean_absolute_error: 2.7414
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.7096 - mean_absolute_error: 1.8306 - val_loss: 10.7883 - val_mean_absolute_error: 2.6621
# Epoch 76/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.2490 - mean_absolute_error: 1.7694 - val_loss: 11.0052 - val_mean_absolute_error: 2.5973
# Epoch 77/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.3908 - mean_absolute_error: 1.8101 - val_loss: 12.0497 - val_mean_absolute_error: 2.5476
# Epoch 78/100
# 7/7 [==============================] - 0s 10ms/step - loss: 7.5500 - mean_absolute_error: 2.2130 - val_loss: 13.0117 - val_mean_absolute_error: 2.5536
# Epoch 79/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.6778 - mean_absolute_error: 2.0544 - val_loss: 12.3871 - val_mean_absolute_error: 2.5241
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 9.5478 - mean_absolute_error: 2.5525 - val_loss: 10.6878 - val_mean_absolute_error: 2.5846
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7.3758 - mean_absolute_error: 2.1232 - val_loss: 10.7829 - val_mean_absolute_error: 2.5578
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.6443 - mean_absolute_error: 2.0321 - val_loss: 10.9895 - val_mean_absolute_error: 2.7590
# Epoch 83/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.1950 - mean_absolute_error: 1.7776 - val_loss: 10.9559 - val_mean_absolute_error: 2.7285
# Epoch 84/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.1437 - mean_absolute_error: 1.7562 - val_loss: 10.7940 - val_mean_absolute_error: 2.6822
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.7998 - mean_absolute_error: 1.6845 - val_loss: 10.6221 - val_mean_absolute_error: 2.5697
# Epoch 86/100
# 7/7 [==============================] - 0s 12ms/step - loss: 4.8873 - mean_absolute_error: 1.7210 - val_loss: 10.8271 - val_mean_absolute_error: 2.6864
# Epoch 87/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.7718 - mean_absolute_error: 1.6864 - val_loss: 11.3864 - val_mean_absolute_error: 2.8156
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.7220 - mean_absolute_error: 1.6873 - val_loss: 11.6295 - val_mean_absolute_error: 2.8563
# Epoch 89/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.2239 - mean_absolute_error: 1.7737 - val_loss: 10.6794 - val_mean_absolute_error: 2.6280
# Epoch 90/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9666 - mean_absolute_error: 1.7088 - val_loss: 11.1088 - val_mean_absolute_error: 2.4315
# Epoch 91/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.2452 - mean_absolute_error: 1.8416 - val_loss: 10.6388 - val_mean_absolute_error: 2.5030
# Epoch 92/100
# 7/7 [==============================] - 0s 13ms/step - loss: 6.9473 - mean_absolute_error: 2.0973 - val_loss: 10.9655 - val_mean_absolute_error: 2.4256
# Epoch 93/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7.6037 - mean_absolute_error: 2.2472 - val_loss: 12.7591 - val_mean_absolute_error: 3.0330
# Epoch 94/100
# 7/7 [==============================] - 0s 10ms/step - loss: 7.0527 - mean_absolute_error: 2.1097 - val_loss: 15.3946 - val_mean_absolute_error: 3.3528
# Epoch 95/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.9156 - mean_absolute_error: 1.9202 - val_loss: 10.9798 - val_mean_absolute_error: 2.7142
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.7772 - mean_absolute_error: 1.6973 - val_loss: 10.7742 - val_mean_absolute_error: 2.5348
# Epoch 97/100
# 7/7 [==============================] - 0s 11ms/step - loss: 4.6655 - mean_absolute_error: 1.6945 - val_loss: 11.0089 - val_mean_absolute_error: 2.6864
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6436 - mean_absolute_error: 1.6747 - val_loss: 10.9283 - val_mean_absolute_error: 2.6456
# Epoch 99/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.9644 - mean_absolute_error: 1.7829 - val_loss: 11.1932 - val_mean_absolute_error: 2.7209
# Epoch 100/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.5949 - mean_absolute_error: 1.6667 - val_loss: 10.7027 - val_mean_absolute_error: 2.5702

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Test Predictions', 'Test Observations'])
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

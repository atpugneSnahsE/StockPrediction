# %%
import pandas as pd
df = pd.read_csv('MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060524
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062686
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063767
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062145
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061065
# ...          ...         ...         ...         ...         ...         ...
# 9410  2023-07-17  345.679993  346.989990  342.200012  345.730011  345.730011
# 9411  2023-07-18  345.829987  366.779999  342.170013  359.489990  359.489990
# 9412  2023-07-19  361.750000  362.459991  352.440002  355.079987  355.079987
# 9413  2023-07-20  353.570007  357.970001  345.369995  346.869995  346.869995
# 9414  2023-07-21  349.149994  350.299988  339.829987  343.769989  343.769989
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9410    20363900
# 9411    64872700
# 9412    39732900
# 9413    33778400
# 9414    69368900
#
# [9415 rows x 7 columns]

# %%
df = df[['Date', 'Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9410  2023-07-17  345.730011
# 9411  2023-07-18  359.489990
# 9412  2023-07-19  355.079987
# 9413  2023-07-20  346.869995
# 9414  2023-07-21  343.769989
#
# [9415 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9410    2023-07-17
# 9411    2023-07-18
# 9412    2023-07-19
# 9413    2023-07-20
# 9414    2023-07-21
# Name: Date, Length: 9415, dtype: object

# %%
from os.path import split
import datetime
def str_to_datetime(s):
  split=s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)
  datetime_object = str_to_datetime('1986-03-19')

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-33-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9410   2023-07-17
# 9411   2023-07-18
# 9412   2023-07-19
# 9413   2023-07-20
# 9414   2023-07-21
# Name: Date, Length: 9415, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f21e11082431> in <cell line: 1>()
# ----> 1 df.index = df.pop('Date')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pop(self, item)
#    5683         3  monkey        NaN
#    5684         """
# -> 5685         return super().pop(item=item)
#    5686
#    5687     # error: Signature of "replace" incompatible with supertype "NDFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in pop(self, item)
#     921
#     922     def pop(self, item: Hashable) -> Series | Any:
# --> 923         result = self[item]
#     924         del self[item]
#     925
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
import matplotlib.pyplot as plt
plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 9s 89ms/step - loss: 84697.4141 - mean_absolute_error: 289.2931 - val_loss: 92188.1875 - val_mean_absolute_error: 303.5379
# Epoch 2/100
# 7/7 [==============================] - 0s 10ms/step - loss: 84163.2344 - mean_absolute_error: 288.3644 - val_loss: 91667.3203 - val_mean_absolute_error: 302.6786
# Epoch 3/100
# 7/7 [==============================] - 0s 10ms/step - loss: 83697.6797 - mean_absolute_error: 287.5524 - val_loss: 91211.8594 - val_mean_absolute_error: 301.9253
# Epoch 4/100
# 7/7 [==============================] - 0s 10ms/step - loss: 83239.2031 - mean_absolute_error: 286.7531 - val_loss: 90627.4062 - val_mean_absolute_error: 300.9559
# Epoch 5/100
# 7/7 [==============================] - 0s 13ms/step - loss: 82546.6172 - mean_absolute_error: 285.5437 - val_loss: 89625.7969 - val_mean_absolute_error: 299.2872
# Epoch 6/100
# 7/7 [==============================] - 0s 14ms/step - loss: 81447.1875 - mean_absolute_error: 283.6159 - val_loss: 88328.2969 - val_mean_absolute_error: 297.1117
# Epoch 7/100
# 7/7 [==============================] - 0s 10ms/step - loss: 80156.7812 - mean_absolute_error: 281.3329 - val_loss: 86735.9922 - val_mean_absolute_error: 294.4197
# Epoch 8/100
# 7/7 [==============================] - 0s 13ms/step - loss: 78435.8594 - mean_absolute_error: 278.2464 - val_loss: 84606.2109 - val_mean_absolute_error: 290.7803
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 76227.5703 - mean_absolute_error: 274.2645 - val_loss: 81825.9297 - val_mean_absolute_error: 285.9595
# Epoch 10/100
# 7/7 [==============================] - 0s 10ms/step - loss: 73187.2266 - mean_absolute_error: 268.6548 - val_loss: 78101.4375 - val_mean_absolute_error: 279.3714
# Epoch 11/100
# 7/7 [==============================] - 0s 10ms/step - loss: 69355.5078 - mean_absolute_error: 261.3987 - val_loss: 73161.8203 - val_mean_absolute_error: 270.3861
# Epoch 12/100
# 7/7 [==============================] - 0s 13ms/step - loss: 64413.9453 - mean_absolute_error: 251.8032 - val_loss: 67975.1562 - val_mean_absolute_error: 260.6187
# Epoch 13/100
# 7/7 [==============================] - 0s 11ms/step - loss: 59339.4062 - mean_absolute_error: 241.4656 - val_loss: 61896.2305 - val_mean_absolute_error: 248.6825
# Epoch 14/100
# 7/7 [==============================] - 0s 11ms/step - loss: 53159.5469 - mean_absolute_error: 228.3126 - val_loss: 54760.2812 - val_mean_absolute_error: 233.8957
# Epoch 15/100
# 7/7 [==============================] - 0s 10ms/step - loss: 46413.2969 - mean_absolute_error: 213.0689 - val_loss: 47524.5039 - val_mean_absolute_error: 217.8794
# Epoch 16/100
# 7/7 [==============================] - 0s 10ms/step - loss: 39509.7227 - mean_absolute_error: 196.1660 - val_loss: 39605.4609 - val_mean_absolute_error: 198.8780
# Epoch 17/100
# 7/7 [==============================] - 0s 9ms/step - loss: 32219.5391 - mean_absolute_error: 176.4259 - val_loss: 32022.4434 - val_mean_absolute_error: 178.8001
# Epoch 18/100
# 7/7 [==============================] - 0s 10ms/step - loss: 25398.3379 - mean_absolute_error: 156.0243 - val_loss: 24847.6309 - val_mean_absolute_error: 157.4624
# Epoch 19/100
# 7/7 [==============================] - 0s 11ms/step - loss: 18828.3164 - mean_absolute_error: 133.1465 - val_loss: 17580.3789 - val_mean_absolute_error: 132.3911
# Epoch 20/100
# 7/7 [==============================] - 0s 13ms/step - loss: 12825.2861 - mean_absolute_error: 108.6625 - val_loss: 11938.2549 - val_mean_absolute_error: 109.0196
# Epoch 21/100
# 7/7 [==============================] - 0s 10ms/step - loss: 8386.8145 - mean_absolute_error: 85.2677 - val_loss: 7360.9126 - val_mean_absolute_error: 85.4840
# Epoch 22/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4844.7803 - mean_absolute_error: 61.9645 - val_loss: 4109.8608 - val_mean_absolute_error: 63.6938
# Epoch 23/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2745.1287 - mean_absolute_error: 42.6846 - val_loss: 2106.6887 - val_mean_absolute_error: 45.3181
# Epoch 24/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1632.1461 - mean_absolute_error: 33.0175 - val_loss: 985.2395 - val_mean_absolute_error: 30.5332
# Epoch 25/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1160.7256 - mean_absolute_error: 28.6658 - val_loss: 453.5881 - val_mean_absolute_error: 20.0157
# Epoch 26/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1024.1931 - mean_absolute_error: 27.0104 - val_loss: 245.7444 - val_mean_absolute_error: 14.0316
# Epoch 27/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1015.0068 - mean_absolute_error: 26.9535 - val_loss: 178.3501 - val_mean_absolute_error: 11.5597
# Epoch 28/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1026.4908 - mean_absolute_error: 27.0385 - val_loss: 164.5853 - val_mean_absolute_error: 10.9778
# Epoch 29/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1027.1213 - mean_absolute_error: 27.0315 - val_loss: 180.5738 - val_mean_absolute_error: 11.6506
# Epoch 30/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1023.6488 - mean_absolute_error: 27.0579 - val_loss: 211.7412 - val_mean_absolute_error: 12.8505
# Epoch 31/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1013.8179 - mean_absolute_error: 26.9189 - val_loss: 224.8602 - val_mean_absolute_error: 13.3199
# Epoch 32/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1011.8129 - mean_absolute_error: 26.9093 - val_loss: 248.0935 - val_mean_absolute_error: 14.1092
# Epoch 33/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1011.0821 - mean_absolute_error: 26.8697 - val_loss: 266.4984 - val_mean_absolute_error: 14.7017
# Epoch 34/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.2518 - mean_absolute_error: 26.8526 - val_loss: 278.2992 - val_mean_absolute_error: 15.0682
# Epoch 35/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.0803 - mean_absolute_error: 26.8621 - val_loss: 281.4448 - val_mean_absolute_error: 15.1642
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1009.4700 - mean_absolute_error: 26.8548 - val_loss: 272.5861 - val_mean_absolute_error: 14.8920
# Epoch 37/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1009.9235 - mean_absolute_error: 26.8550 - val_loss: 264.3449 - val_mean_absolute_error: 14.6337
# Epoch 38/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.4772 - mean_absolute_error: 26.8694 - val_loss: 272.0182 - val_mean_absolute_error: 14.8743
# Epoch 39/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1009.8533 - mean_absolute_error: 26.8546 - val_loss: 264.7309 - val_mean_absolute_error: 14.6460
# Epoch 40/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1009.7151 - mean_absolute_error: 26.8560 - val_loss: 256.5619 - val_mean_absolute_error: 14.3852
# Epoch 41/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.4236 - mean_absolute_error: 26.8710 - val_loss: 251.4196 - val_mean_absolute_error: 14.2184
# Epoch 42/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.6932 - mean_absolute_error: 26.8803 - val_loss: 260.4972 - val_mean_absolute_error: 14.5115
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1011.0440 - mean_absolute_error: 26.8750 - val_loss: 254.0044 - val_mean_absolute_error: 14.3026
# Epoch 44/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1007.9787 - mean_absolute_error: 26.8288 - val_loss: 276.0790 - val_mean_absolute_error: 15.0033
# Epoch 45/100
# 7/7 [==============================] - 0s 12ms/step - loss: 986.8671 - mean_absolute_error: 26.6567 - val_loss: 492.0116 - val_mean_absolute_error: 20.9866
# Epoch 46/100
# 7/7 [==============================] - 0s 13ms/step - loss: 982.2505 - mean_absolute_error: 26.5315 - val_loss: 259.5128 - val_mean_absolute_error: 14.4983
# Epoch 47/100
# 7/7 [==============================] - 0s 10ms/step - loss: 988.1707 - mean_absolute_error: 26.5676 - val_loss: 238.1151 - val_mean_absolute_error: 13.7890
# Epoch 48/100
# 7/7 [==============================] - 0s 11ms/step - loss: 985.0847 - mean_absolute_error: 26.4799 - val_loss: 288.1769 - val_mean_absolute_error: 15.3853
# Epoch 49/100
# 7/7 [==============================] - 0s 11ms/step - loss: 952.2750 - mean_absolute_error: 26.0458 - val_loss: 469.8740 - val_mean_absolute_error: 20.4841
# Epoch 50/100
# 7/7 [==============================] - 0s 10ms/step - loss: 935.7872 - mean_absolute_error: 25.7506 - val_loss: 260.3549 - val_mean_absolute_error: 14.5569
# Epoch 51/100
# 7/7 [==============================] - 0s 10ms/step - loss: 938.2609 - mean_absolute_error: 25.8983 - val_loss: 234.4163 - val_mean_absolute_error: 13.7081
# Epoch 52/100
# 7/7 [==============================] - 0s 10ms/step - loss: 888.4799 - mean_absolute_error: 25.1582 - val_loss: 534.1995 - val_mean_absolute_error: 22.0440
# Epoch 53/100
# 7/7 [==============================] - 0s 16ms/step - loss: 882.4611 - mean_absolute_error: 25.2342 - val_loss: 243.2838 - val_mean_absolute_error: 14.0559
# Epoch 54/100
# 7/7 [==============================] - 0s 10ms/step - loss: 808.5324 - mean_absolute_error: 23.9560 - val_loss: 202.5071 - val_mean_absolute_error: 12.6526
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 761.1633 - mean_absolute_error: 23.3773 - val_loss: 180.9085 - val_mean_absolute_error: 11.8742
# Epoch 56/100
# 7/7 [==============================] - 0s 10ms/step - loss: 711.4174 - mean_absolute_error: 22.5268 - val_loss: 316.8075 - val_mean_absolute_error: 16.5954
# Epoch 57/100
# 7/7 [==============================] - 0s 10ms/step - loss: 618.3795 - mean_absolute_error: 20.7927 - val_loss: 205.3025 - val_mean_absolute_error: 12.8996
# Epoch 58/100
# 7/7 [==============================] - 0s 11ms/step - loss: 556.0124 - mean_absolute_error: 19.7535 - val_loss: 256.5350 - val_mean_absolute_error: 14.7764
# Epoch 59/100
# 7/7 [==============================] - 0s 14ms/step - loss: 501.8827 - mean_absolute_error: 18.6992 - val_loss: 106.8143 - val_mean_absolute_error: 8.7159
# Epoch 60/100
# 7/7 [==============================] - 0s 13ms/step - loss: 459.0132 - mean_absolute_error: 17.9766 - val_loss: 124.0810 - val_mean_absolute_error: 9.6348
# Epoch 61/100
# 7/7 [==============================] - 0s 10ms/step - loss: 419.3415 - mean_absolute_error: 16.7951 - val_loss: 105.5670 - val_mean_absolute_error: 8.7361
# Epoch 62/100
# 7/7 [==============================] - 0s 10ms/step - loss: 361.9411 - mean_absolute_error: 15.6773 - val_loss: 136.3511 - val_mean_absolute_error: 10.2863
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 314.9001 - mean_absolute_error: 14.3565 - val_loss: 184.8823 - val_mean_absolute_error: 12.3621
# Epoch 64/100
# 7/7 [==============================] - 0s 10ms/step - loss: 269.6563 - mean_absolute_error: 13.2335 - val_loss: 38.2596 - val_mean_absolute_error: 5.1490
# Epoch 65/100
# 7/7 [==============================] - 0s 10ms/step - loss: 236.5577 - mean_absolute_error: 12.4179 - val_loss: 43.7984 - val_mean_absolute_error: 5.3943
# Epoch 66/100
# 7/7 [==============================] - 0s 10ms/step - loss: 198.9082 - mean_absolute_error: 11.2501 - val_loss: 41.3689 - val_mean_absolute_error: 5.3381
# Epoch 67/100
# 7/7 [==============================] - 0s 11ms/step - loss: 166.7807 - mean_absolute_error: 10.0300 - val_loss: 31.7931 - val_mean_absolute_error: 4.8747
# Epoch 68/100
# 7/7 [==============================] - 0s 13ms/step - loss: 149.2262 - mean_absolute_error: 9.6962 - val_loss: 31.1598 - val_mean_absolute_error: 4.8660
# Epoch 69/100
# 7/7 [==============================] - 0s 10ms/step - loss: 116.7049 - mean_absolute_error: 8.5804 - val_loss: 31.7839 - val_mean_absolute_error: 4.9826
# Epoch 70/100
# 7/7 [==============================] - 0s 11ms/step - loss: 95.5467 - mean_absolute_error: 7.4782 - val_loss: 49.9491 - val_mean_absolute_error: 5.9781
# Epoch 71/100
# 7/7 [==============================] - 0s 11ms/step - loss: 78.1503 - mean_absolute_error: 6.7037 - val_loss: 35.0617 - val_mean_absolute_error: 5.1537
# Epoch 72/100
# 7/7 [==============================] - 0s 10ms/step - loss: 64.1389 - mean_absolute_error: 6.0778 - val_loss: 33.1116 - val_mean_absolute_error: 4.8708
# Epoch 73/100
# 7/7 [==============================] - 0s 10ms/step - loss: 53.2608 - mean_absolute_error: 5.3837 - val_loss: 30.3751 - val_mean_absolute_error: 4.8199
# Epoch 74/100
# 7/7 [==============================] - 0s 10ms/step - loss: 47.8488 - mean_absolute_error: 5.1465 - val_loss: 33.1485 - val_mean_absolute_error: 5.0027
# Epoch 75/100
# 7/7 [==============================] - 0s 10ms/step - loss: 47.5378 - mean_absolute_error: 5.3430 - val_loss: 36.3649 - val_mean_absolute_error: 4.8997
# Epoch 76/100
# 7/7 [==============================] - 0s 10ms/step - loss: 43.9772 - mean_absolute_error: 5.1730 - val_loss: 76.9928 - val_mean_absolute_error: 7.0635
# Epoch 77/100
# 7/7 [==============================] - 0s 12ms/step - loss: 43.0641 - mean_absolute_error: 5.3652 - val_loss: 43.7018 - val_mean_absolute_error: 5.1909
# Epoch 78/100
# 7/7 [==============================] - 0s 9ms/step - loss: 31.4762 - mean_absolute_error: 4.2420 - val_loss: 40.8113 - val_mean_absolute_error: 5.0549
# Epoch 79/100
# 7/7 [==============================] - 0s 10ms/step - loss: 29.1333 - mean_absolute_error: 4.1950 - val_loss: 38.8788 - val_mean_absolute_error: 4.9623
# Epoch 80/100
# 7/7 [==============================] - 0s 13ms/step - loss: 27.2556 - mean_absolute_error: 3.9845 - val_loss: 45.9723 - val_mean_absolute_error: 5.3606
# Epoch 81/100
# 7/7 [==============================] - 0s 13ms/step - loss: 25.5412 - mean_absolute_error: 3.9462 - val_loss: 54.2534 - val_mean_absolute_error: 5.7842
# Epoch 82/100
# 7/7 [==============================] - 0s 10ms/step - loss: 24.7811 - mean_absolute_error: 3.8870 - val_loss: 41.8974 - val_mean_absolute_error: 5.1250
# Epoch 83/100
# 7/7 [==============================] - 0s 14ms/step - loss: 24.7819 - mean_absolute_error: 3.9149 - val_loss: 54.3578 - val_mean_absolute_error: 5.8008
# Epoch 84/100
# 7/7 [==============================] - 0s 10ms/step - loss: 24.6730 - mean_absolute_error: 4.0742 - val_loss: 60.6376 - val_mean_absolute_error: 6.1043
# Epoch 85/100
# 7/7 [==============================] - 0s 10ms/step - loss: 25.7776 - mean_absolute_error: 4.0569 - val_loss: 38.1164 - val_mean_absolute_error: 4.9271
# Epoch 86/100
# 7/7 [==============================] - 0s 11ms/step - loss: 22.3257 - mean_absolute_error: 3.6750 - val_loss: 44.4434 - val_mean_absolute_error: 5.2951
# Epoch 87/100
# 7/7 [==============================] - 0s 10ms/step - loss: 20.5380 - mean_absolute_error: 3.5549 - val_loss: 63.1768 - val_mean_absolute_error: 6.2499
# Epoch 88/100
# 7/7 [==============================] - 0s 10ms/step - loss: 21.7929 - mean_absolute_error: 3.6706 - val_loss: 41.8265 - val_mean_absolute_error: 5.1300
# Epoch 89/100
# 7/7 [==============================] - 0s 10ms/step - loss: 23.1308 - mean_absolute_error: 3.8440 - val_loss: 57.7736 - val_mean_absolute_error: 5.9875
# Epoch 90/100
# 7/7 [==============================] - 0s 10ms/step - loss: 20.5544 - mean_absolute_error: 3.6252 - val_loss: 62.3707 - val_mean_absolute_error: 6.2516
# Epoch 91/100
# 7/7 [==============================] - 0s 13ms/step - loss: 23.3610 - mean_absolute_error: 3.8965 - val_loss: 37.6790 - val_mean_absolute_error: 4.9203
# Epoch 92/100
# 7/7 [==============================] - 0s 10ms/step - loss: 21.4179 - mean_absolute_error: 3.5789 - val_loss: 39.6375 - val_mean_absolute_error: 5.0227
# Epoch 93/100
# 7/7 [==============================] - 0s 10ms/step - loss: 21.3657 - mean_absolute_error: 3.7454 - val_loss: 77.1610 - val_mean_absolute_error: 7.1009
# Epoch 94/100
# 7/7 [==============================] - 0s 10ms/step - loss: 22.8352 - mean_absolute_error: 3.7008 - val_loss: 34.1733 - val_mean_absolute_error: 4.8135
# Epoch 95/100
# 7/7 [==============================] - 0s 9ms/step - loss: 23.0752 - mean_absolute_error: 3.7589 - val_loss: 34.9529 - val_mean_absolute_error: 4.8238
# Epoch 96/100
# 7/7 [==============================] - 0s 14ms/step - loss: 21.7222 - mean_absolute_error: 3.7328 - val_loss: 82.9812 - val_mean_absolute_error: 7.4180
# Epoch 97/100
# 7/7 [==============================] - 0s 12ms/step - loss: 28.0817 - mean_absolute_error: 4.1335 - val_loss: 54.2272 - val_mean_absolute_error: 5.8199
# Epoch 98/100
# 7/7 [==============================] - 0s 18ms/step - loss: 20.8574 - mean_absolute_error: 3.5793 - val_loss: 62.4089 - val_mean_absolute_error: 6.2844
# Epoch 99/100
# 7/7 [==============================] - 0s 16ms/step - loss: 17.7766 - mean_absolute_error: 3.3186 - val_loss: 49.6253 - val_mean_absolute_error: 5.6065
# Epoch 100/100
# 7/7 [==============================] - 0s 16ms/step - loss: 17.0400 - mean_absolute_error: 3.2589 - val_loss: 36.3732 - val_mean_absolute_error: 4.8681

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 4ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Test Predictions', 'Test Observations'])
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
